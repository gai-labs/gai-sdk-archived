# %% [markdown]
# # Gai/Gen: Text-to-Image (TTI)
#
# ## 1.1 Setting Up
#
# We will create a seperate virtual environment for this to avoid conflicting dependencies that each underlying model requires.
#
# ```sh
# conda create -n TTI python=3.10.10 -y
# conda activate TTI
# pip install ".[TTI]"
# ```

# %%
## 2.1 OpenAI DALL-E 3

print("GENERATING:")
from gai.gen import Gaigen
gen = Gaigen.GetInstance("./gai.json")
gen.load('openai-dalle3')
bytes = gen.create(
  messages="a white siamese cat"  
)
from PIL import Image
from io import BytesIO
Image.open(BytesIO(bytes))
# Out:
# 2024-05-31 09:45:35 DEBUG gai.gen.Gaigen:Gaigen.load: Generator is already loaded. Skip loading.
# GENERATING:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %%
print(type(response.content))
# Out:
# <class 'bytes'>

# %%
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(response.json())
#
# File ~/miniconda/envs/TTI/lib/python3.10/site-packages/httpx/_models.py:755, in Response.json(self, **kwargs)
#     753     encoding = guess_json_utf(self.content)
#     754     if encoding is not None:
# --> 755         return jsonlib.loads(self.content.decode(encoding), **kwargs)
#     756 return jsonlib.loads(self.text, **kwargs)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
