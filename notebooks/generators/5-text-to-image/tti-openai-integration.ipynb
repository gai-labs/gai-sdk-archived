# %% [markdown]
# ## 2 Examples
#
# ### 2.1 OpenAI DALL-E 3

# %%
## 2.1 OpenAI DALL-E 3

print("GENERATING:")
from gai.gen import Gaigen
gen = Gaigen.GetInstance("../../gai-gen/gai.json")
gen.load('openai-dalle3')
response = gen.create(messages="a white siamese cat")
from PIL import Image
from io import BytesIO
img = Image.open(BytesIO(response))
img
# Out:
# 2024-06-04 21:49:11 DEBUG gai.gen.Gaigen:Gaigen.load: Generator is already loaded. Skip loading.
# GENERATING:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
